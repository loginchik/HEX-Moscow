# %%
import math 
import json 

import geopandas as gpd
import h3
import pandas as pd
from shapely.geometry.polygon import Polygon

# %% [markdown]
# Загрузим данные.

# %%
gdf = gpd.read_file('data/buildings.gpkg')

# %%
gdf.columns
# Out:
# Index(['cad_num', 'cost_value', 'year_built', 'floors', 'materials', 'purpose',
#        'area', 'rayon', 'geometry'],
#       dtype='object')

# %% [markdown]
# Определим гексы, к которым относятся здания, опираясь на центроиду.

# %%
def define_hex(x):
    center = x.centroid
    return h3.geo_to_h3(center.x, center.y, 7)

# %%
gdf['h'] = gdf.geometry.apply(define_hex)

# %%
len(gdf['h'].unique())
# Out:
# 31

# %% [markdown]
# При разрешении в 7 получается 31 гексагон.

# %%
gdf['h'].value_counts(normalize=True)
# Out:
# h
# 872cce8c9ffffff    0.098760
# 872cce164ffffff    0.095778
# 872cce8cbffffff    0.088263
# 872cce8d9ffffff    0.086772
# 872cce166ffffff    0.066734
# 872cce8caffffff    0.063633
# 872cceb94ffffff    0.060472
# 872cce8c8ffffff    0.056119
# 872cceb96ffffff    0.049380
# 872ccebb2ffffff    0.043714
# 872ccebb3ffffff    0.042283
# 872cce160ffffff    0.033993
# 872cce165ffffff    0.031966
# 872cce8dbffffff    0.028865
# 872cce8cdffffff    0.026121
# 872cce175ffffff    0.025763
# 872cce8d8ffffff    0.018667
# 872cce8daffffff    0.014850
# 872cce174ffffff    0.014074
# 872ccebb6ffffff    0.011033
# 872cce176ffffff    0.010496
# 872cce8ddffffff    0.009721
# 872ccebb0ffffff    0.006620
# 872cce170ffffff    0.006143
# 872ccebb1ffffff    0.005069
# 872cce8ceffffff    0.003698
# 872cceb86ffffff    0.000417
# 872cceb92ffffff    0.000239
# 872cce129ffffff    0.000179
# 872cceb90ffffff    0.000119
# 872cceb95ffffff    0.000060
# Name: proportion, dtype: float64

# %% [markdown]
# Создадим новый геодатафрейм - с данными по каждому гексу. И первым делом отбросим те гексы, где менее 100 зданий - слишком уж нерепрезентативно по такому маленькому количеству данных делать статистические выводы.
#
# Посчитаем количество домов, которые входят в гекс, общую кадастровую стоимость недвижимости, средний и максимальный год постройки здания, среднее и максимальное количество этажей от максимального количества этажей (см. подготоку данных) в зданиях.

# %%
hexes = pd.pivot_table(data=gdf, index='h', aggfunc={
    'cad_num': 'count',
    'cost_value': 'sum', 
    'year_built': ['mean', 'max'],
    'floors': ['mean', 'max'], 
    
})

hexes = hexes[hexes[('cad_num', 'count')] >= 100]
hexes[('floors', 'max')] = hexes[('floors', 'max')].astype(int)
hexes[('floors', 'mean')] = hexes[('floors', 'mean')].apply(lambda x: int(math.ceil(x)))
hexes[('year_built', 'max')] = hexes[('year_built', 'max')].astype(int)
hexes[('year_built', 'mean')] = hexes[('year_built', 'mean')].apply(lambda x: int(math.floor(x)))

# %% [markdown]
# В итоге получается вот такой набор цифр:

# %%
hexes
# Out:
#                 cad_num    cost_value floors      year_built
#                   count           sum    max mean        max  mean
# h
# 872cce160ffffff     570  3.864451e+11     18    5       2018  1946
# 872cce164ffffff    1606  1.480858e+12     19    4       2021  1923
# 872cce165ffffff     536  4.408207e+11     39    5       2020  1949
# 872cce166ffffff    1119  1.067231e+12     31    5       2021  1940
# 872cce170ffffff     103  3.048329e+10     14    3       2014  1968
# 872cce174ffffff     236  5.049558e+11     80    7       2022  1964
# 872cce175ffffff     432  3.011344e+11     22    5       2021  1954
# 872cce176ffffff     176  1.529099e+11     88    6       2020  1974
# 872cce8c8ffffff     941  7.062743e+11     35    5       2021  1931
# 872cce8c9ffffff    1656  8.789334e+11     33    4       2023  1921
# 872cce8caffffff    1067  9.410942e+11     22    4       2022  1934
# 872cce8cbffffff    1480  1.179341e+12     15    4       2016  1911
# 872cce8cdffffff     438  3.148997e+11     24    5       2016  1936
# 872cce8d8ffffff     313  6.374254e+11     20    5       2021  1956
# 872cce8d9ffffff    1455  1.580587e+12     26    4       2021  1928
# 872cce8daffffff     249  1.872230e+11     14    4       2021  1940
# 872cce8dbffffff     484  6.020069e+11     34    5       2023  1941
# 872cce8ddffffff     163  1.289526e+11     23    4       2021  1933
# 872cceb94ffffff    1014  4.504654e+11     22    4       2016  1940
# 872cceb96ffffff     828  6.377086e+11     29    5       2022  1945
# 872ccebb0ffffff     111  7.880786e+10     25    6       2020  1974
# 872ccebb2ffffff     733  4.544069e+11     23    4       2022  1938
# 872ccebb3ffffff     709  2.818650e+11     22    4       2021  1945
# 872ccebb6ffffff     185  1.077797e+11     19    5       2015  1956

# %% [markdown]
# Теперь переведём эти данные в геоформат, чтобы была возможность оперировать геометрией гексов.

# %%
hexes_geo = pd.DataFrame()
hexes['id'] = hexes.index
hexes_geo['id'] = hexes[('id', '')]
hexes_geo['buildings_count'] = hexes[('cad_num', 'count')]
hexes_geo['cost'] = hexes[('cost_value', 'sum')]
hexes_geo['max_floors'] = hexes[('floors', 'max')]
hexes_geo['mean_floors'] = hexes[('floors', 'mean')]
hexes_geo['year_mean'] = hexes[('year_built', 'mean')]
hexes_geo['geometry'] = hexes_geo['id'].apply(lambda x: Polygon(h3.h3_to_geo_boundary(x, False)))

hexes_geo = gpd.GeoDataFrame(hexes_geo, geometry='geometry', crs=4326)
hexes_geo = hexes_geo.to_crs(3857)
hexes_geo = hexes_geo.reset_index(drop=True)

# %%
hexes_geo['year_max'] = hexes_geo['max_floors'].apply(lambda x: gdf[gdf['floors'] == x]['year_built'].min()).astype(int)

# %% [markdown]
# Вот, собственно говоря, те самые гексы, ради которых всё и затевалось:

# %%
hexes_geo.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c25fad3819ef46099a8fdb2d790bea73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c25fad3819ef46099a8fdb2d790bea73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c25fad3819ef46099a8fdb2d790bea73 = L.map(
#                 &quot;map_c25fad3819ef46099a8fdb2d790bea73&quot;,
#                 {
#                     center: [55.75189687074335, 37.61101758057975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c25fad3819ef46099a8fdb2d790bea73);
#
#
#
#
#
#             var tile_layer_0dcae5da9caed59fb0099c43815b3cb8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0dcae5da9caed59fb0099c43815b3cb8.addTo(map_c25fad3819ef46099a8fdb2d790bea73);
#
#
#             map_c25fad3819ef46099a8fdb2d790bea73.fitBounds(
#                 [[55.69710768425549, 37.51179730633846], [55.80668605723122, 37.71023785482104]],
#                 {}
#             );
#
#
#         function geo_json_9e712e8aaac17e26ea78347ca8eff883_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_9e712e8aaac17e26ea78347ca8eff883_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9e712e8aaac17e26ea78347ca8eff883_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_9e712e8aaac17e26ea78347ca8eff883_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_9e712e8aaac17e26ea78347ca8eff883_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_9e712e8aaac17e26ea78347ca8eff883.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9e712e8aaac17e26ea78347ca8eff883_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9e712e8aaac17e26ea78347ca8eff883 = L.geoJson(null, {
#                 onEachFeature: geo_json_9e712e8aaac17e26ea78347ca8eff883_onEachFeature,
#
#                 style: geo_json_9e712e8aaac17e26ea78347ca8eff883_styler,
#                 pointToLayer: geo_json_9e712e8aaac17e26ea78347ca8eff883_pointToLayer,
#         });
#
#         function geo_json_9e712e8aaac17e26ea78347ca8eff883_add (data) {
#             geo_json_9e712e8aaac17e26ea78347ca8eff883
#                 .addData(data);
#         }
#             geo_json_9e712e8aaac17e26ea78347ca8eff883_add({&quot;bbox&quot;: [37.51179730633846, 55.69710768425549, 37.71023785482104, 55.80668605723122], &quot;features&quot;: [{&quot;bbox&quot;: [37.51179730633846, 55.73706172416753, 37.53623800101486, 55.77007157312753], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[37.52244844654404, 55.73706172416753], [37.51179730633846, 55.747476313256485], [37.51336404945316, 55.76397839817627], [37.525583746194094, 55.77007157312753], [37.53623800101486, 55.75965730318646], [37.53466944400098, 55.743149537655555], [37.52244844654404, 55.73706172416753]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;buildings_count&quot;: 176, &quot;commercial_ratio&quot;: 0.6363636363636364, &quot;cost&quot;: 152909889949.1, &quot

# %% [markdown]
# Посчитаем ещё некоторые дополнительные параметры. В первую очередь - долю некоммерческой недвижимости от всей недвижимости, которая входит в гекс.

# %%
purpose_groups = gdf.groupby('h')['purpose'].value_counts(normalize=True)
hexes_geo['commercial_ratio'] = [purpose_groups[(h, 'Нежилое')] for h in hexes_geo['id']]

# %% [markdown]
# Также посчитаем среднюю стоимость дома самым простым способом - поделим итоговую кадастровую стоимость на количество домов. Так как количество домов сильно разнится, средняя стоимость будет более адекватным показателем "дороговизны" имущества.

# %%
hexes_geo['cost_mean'] = hexes_geo['cost'] / hexes_geo['buildings_count']

# %%
hexes_geo
# Out:
#                  id  buildings_count          cost  max_floors  mean_floors  \
# 0   872cce160ffffff              570  3.864451e+11          18            5
# 1   872cce164ffffff             1606  1.480858e+12          19            4
# 2   872cce165ffffff              536  4.408207e+11          39            5
# 3   872cce166ffffff             1119  1.067231e+12          31            5
# 4   872cce170ffffff              103  3.048329e+10          14            3
# 5   872cce174ffffff              236  5.049558e+11          80            7
# 6   872cce175ffffff              432  3.011344e+11          22            5
# 7   872cce176ffffff              176  1.529099e+11          88            6
# 8   872cce8c8ffffff              941  7.062743e+11          35            5
# 9   872cce8c9ffffff             1656  8.789334e+11          33            4
# 10  872cce8caffffff             1067  9.410942e+11          22            4
# 11  872cce8cbffffff             1480  1.179341e+12          15            4
# 12  872cce8cdffffff              438  3.148997e+11          24            5
# 13  872cce8d8ffffff              313  6.374254e+11          20            5
# 14  872cce8d9ffffff             1455  1.580587e+12          26            4
# 15  872cce8daffffff              249  1.872230e+11          14            4
# 16  872cce8dbffffff              484  6.020069e+11          34            5
# 17  872cce8ddffffff              163  1.289526e+11          23            4
# 18  872cceb94ffffff             1014  4.504654e+11          22            4
# 19  872cceb96ffffff              828  6.377086e+11          29            5
# 20  872ccebb0ffffff              111  7.880786e+10          25            6
# 21  872ccebb2ffffff              733  4.544069e+11          23            4
# 22  872ccebb3ffffff              709  2.818650e+11          22            4
# 23  872ccebb6ffffff              185  1.077797e+11          19            5
#
#     year_mean                                           geometry  year_max  \
# 0        1946  POLYGON ((4185144.085 7513482.780, 4183957.647...      1979
# 1        1923  POLYGON ((4186155.450 7508150.252, 4184969.327...      1999
# 2        1949  POLYGON ((4187691.636 7512627.139, 4186505.167...      2018
# 3        1940  POLYGON ((4183608.334 7509006.776, 4182422.244...      1954
# 4        1968  POLYGON ((4178514.901 7510718.245, 4177328.874...      1917
# 5        1964  POLYGON ((4179526.002 7505392.810, 4178340.290...      2013
# 6        1954  POLYGON ((4181061.484 7509862.774, 4179875.426...      1974
# 7        1974  POLYGON ((4176979.854 7506249.161, 4175794.175...      2015
# 8        1931  POLYGON ((4189713.248 7501962.138, 4188527.411...      2004
# 9        1921  POLYGON ((4191250.474 7506435.623, 4190064.290...      1953
# 10       1934  POLYGON ((4187166.040 7502820.597, 4185980.233...      1974
# 11       1911  POLYGON ((4188702.830 7507293.201, 4187516.676...      1951
# 12       1936  POLYGON ((4192260.720 7501103.150, 4191074.852...      1967
# 13       1956  POLYGON ((4183082.572 7499211.957, 4181897.143...      1981
# 14       1928  POLYGON ((4184619.095 7503678.528, 4183433.319...      1952
# 15       1940  POLYGON ((4180536.329 7500070.239, 4179350.932...      1917
# 16       1941  POLYGON ((4182072.415 7504535.932, 4180886.671...      1966
# 17       1933  POLYGON ((4185629.081 7498353.148, 4184443.620...      1973
# 18       1940  POLYGON ((4192787.530 7510914.276, 4191600.999...      1974
# 19       1945  POLYGON ((4190239.451 7511770.971, 4189052.951...      1955
# 20       1974  POLYGON ((4196346.551 7504718.882, 4195160.306...      1951
# 21       1938  POLYGON ((4193798.381 7505577.517, 4192612.167...      1973
# 22       1945  POLYGON ((4195335.872 7510057.053, 4194149.311...      1974
# 23       1956  POLYGON ((4194808.455 7500243.635, 4193622.557...      1999
#
#     commercial_ratio     cost_mean
# 0           0.703509  6.779738e+08
# 1           0.735367  9.220788e+08
# 2           0.716418  8.224266e+08
# 3           0.673816  9.537366e+08
# 4           0.757282  2.959543e+08
# 5           0.483051  2.139643e+09
# 6           0.696759  6.970703e+08
# 7           0.636364  8.688062e+08
# 8           0.757705  7.505571e+08
# 9           0.755435  5.307569e+08
# 10          0.827554  8.820002e+08
# 11          0.792568  7.968521e+08
# 12          0.751142  7.189491e+08
# 13          0.581470  2.036503e+09
# 14          0.660481  1.086314e+09
# 15          0.763052  7.518996e+08
# 16          0.710744  1.243816e+09
# 17          0.791411  7.911200e+08
# 18          0.793886  4.442460e+08
# 19          0.753623  7.701795e+08
# 20          0.801802  7.099807e+08
# 21          0.806276  6.199275e+08
# 22          0.805360  3.975529e+08
# 23          0.643243  5.825930e+08

# %% [markdown]
# Нормализуем показатель стоимости - приведём его к такому виду, чтобы он варьировался в диапазоне от 0 до 1, где 0 - минимальная стоимость, 1 - максимальная.

# %%
max_value = hexes_geo['cost_mean'].max()
min_value = hexes_geo['cost_mean'].min()

hexes_geo['cost_mean_normalized'] = hexes_geo['cost_mean'].apply(lambda x: (x - min_value) / (max_value - min_value))

# %% [markdown]
# Теперь подготовим данные к тому, чтобы воссоздать гексагоны в p5js. Для этого нормализуем положение каждого гекса по горизонтальной и вертикальной оси таким образом, чтобы среднее значение было равным 0, а модуль максимального и минимального значения - стандартному отклонению.
#
# Благодаря такому методу нормализации при работе в p5js мы сможем ориентироваться по этим показателям "от центра" картинки.

# %%
hexes_geo['x'] = hexes_geo['geometry'].apply(lambda x: x.centroid.x)
hexes_geo['y'] = hexes_geo['geometry'].apply(lambda x: x.centroid.y)

# %%
hexes_geo['x_normalized'] = hexes_geo['x'].apply(lambda x: (x - hexes_geo['x'].mean()) / hexes_geo['x'].std())
hexes_geo['y_normalized'] = hexes_geo['y'].apply(lambda x: (x - hexes_geo['y'].mean()) / hexes_geo['y'].std())

# %%
hexes_geo = hexes_geo.sort_values(by=['x_normalized', 'y_normalized'])

# %%
hexes_geo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 24 entries, 7 to 20
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    24 non-null     object
#  1   buildings_count       24 non-null     int64
#  2   cost                  24 non-null     float64
#  3   max_floors            24 non-null     int64
#  4   mean_floors           24 non-null     int64
#  5   year_mean             24 non-null     int64
#  6   geometry              24 non-null     geometry
#  7   year_max              24 non-null     int64
#  8   commercial_ratio      24 non-null     float64
#  9   cost_mean             24 non-null     float64
#  10  cost_mean_normalized  24 non-null     float64
#  11  x                     24 non-null     float64
#  12  y                     24 non-null     float64
#  13  x_normalized          24 non-null     float64
#  14  y_normalized          24 non-null     float64
# dtypes: float64(8), geometry(1), int64(5), object(1)
# memory usage: 3.0+ KB

# %%
def normalize_geo(max_value, min_value, median_value, x):
    if x == median_value:
        return 0
    if x > median_value:
        return (x - median_value) / (max_value - median_value)
    
    return (x - median_value) / (min_value - median_value) * -1

# %%
hexes_geo['x_normalized_2'] = hexes_geo['x'].apply(lambda x: normalize_geo(hexes_geo.x.max(), hexes_geo.x.min(), hexes_geo.x.median(), x))
hexes_geo['y_normalized_2'] = hexes_geo['y'].apply(lambda x: normalize_geo(hexes_geo.y.max(), hexes_geo.y.min(), hexes_geo.y.median(), x))

# %%
hexes_geo[hexes_geo['y'] <= hexes_geo['y'].quantile(0.25)]
# Out:
#                  id  buildings_count          cost  max_floors  mean_floors  \
# 15  872cce8daffffff              249  1.872230e+11          14            4
# 13  872cce8d8ffffff              313  6.374254e+11          20            5
# 17  872cce8ddffffff              163  1.289526e+11          23            4
# 8   872cce8c8ffffff              941  7.062743e+11          35            5
# 12  872cce8cdffffff              438  3.148997e+11          24            5
# 23  872ccebb6ffffff              185  1.077797e+11          19            5
#
#     year_mean                                           geometry  year_max  \
# 15       1940  POLYGON ((4180536.329 7500070.239, 4179350.932...      1917
# 13       1956  POLYGON ((4183082.572 7499211.957, 4181897.143...      1981
# 17       1933  POLYGON ((4185629.081 7498353.148, 4184443.620...      1973
# 8        1931  POLYGON ((4189713.248 7501962.138, 4188527.411...      2004
# 12       1936  POLYGON ((4192260.720 7501103.150, 4191074.852...      1967
# 23       1956  POLYGON ((4194808.455 7500243.635, 4193622.557...      1999
#
#     commercial_ratio     cost_mean  cost_mean_normalized             x  \
# 15          0.763052  7.518996e+08              0.247301  4.180712e+06
# 13          0.581470  2.036503e+09              0.944058  4.183258e+06
# 17          0.791411  7.911200e+08              0.268573  4.185805e+06
# 8           0.757705  7.505571e+08              0.246572  4.189889e+06
# 12          0.751142  7.189491e+08              0.229428  4.192437e+06
# 23          0.643243  5.825930e+08              0.155470  4.194985e+06
#
#                y  x_normalized  y_normalized  x_normalized_2  y_normalized_2
# 15  7.503333e+06     -1.138010     -1.329480       -0.632583       -0.773197
# 13  7.502476e+06     -0.686850     -1.521218       -0.369560       -0.886564
# 17  7.501618e+06     -0.235644     -1.713073       -0.106510       -1.000000
# 8   7.505230e+06      0.487948     -0.905246        0.315178       -0.522366
# 12  7.504372e+06      0.939326     -1.097141        0.578194       -0.635825
# 23  7.503514e+06      1.390750     -1.289154        0.841237       -0.749354

# %%
hexes_geo.sort_values(by='y').explore(
    column='y_normalized_2',
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1560e96d36f5d9702d939b5cf8affb1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1560e96d36f5d9702d939b5cf8affb1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1560e96d36f5d9702d939b5cf8affb1c = L.map(
#                 &quot;map_1560e96d36f5d9702d939b5cf8affb1c&quot;,
#                 {
#                     center: [55.75189687074335, 37.61101758057975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1560e96d36f5d9702d939b5cf8affb1c);
#
#
#
#
#
#             var tile_layer_47ae5aa07b1c9dee48cf98adf3a58db0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_47ae5aa07b1c9dee48cf98adf3a58db0.addTo(map_1560e96d36f5d9702d939b5cf8affb1c);
#
#
#             map_1560e96d36f5d9702d939b5cf8affb1c.fitBounds(
#                 [[55.69710768425549, 37.51179730633846], [55.80668605723122, 37.71023785482104]],
#                 {}
#             );
#
#
#         function geo_json_653841b601faf6b2cf43db4f9197d8ae_styler(feature) {
#             switch(feature.id) {
#                 case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#481668&quot;, &quot;fillColor&quot;: &quot;#481668&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#482979&quot;, &quot;fillColor&quot;: &quot;#482979&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;#472d7b&quot;, &quot;fillColor&quot;: &quot;#472d7b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#433e85&quot;, &quot;fillColor&quot;: &quot;#433e85&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#3c4f8a&quot;, &quot;fillColor&quot;: &quot;#3c4f8a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#355e8d&quot;, &quot;fillColor&quot;: &quot;#355e8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#2e6d8e&quot;, &quot;fillColor&quot;: &quot;#2e6d8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;#297a8e&quot;, &quot;fillColor&quot;: &quot;#297a8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;#287d8e&quot;, &quot;fillColor&quot;: &quot;#287d8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#23888e&quot;, &quot;fillColor&quot;: &quot;#23888e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;#228b8d&quot;, &quot;fillColor&quot;: &quot;#228b8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#1f958b&quot;, &quot;fillColor&quot;: &quot;#1f958b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#21a685&quot;, &quot;fillColor&quot;: &quot;#21a685&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#2eb37c&quot;, &quot;fillColor&quot;: &quot;#2eb37c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:

# %% [markdown]
# Сохраним итоговый результат

# %%
hexes_summary = hexes_geo[['cost_mean_normalized', 'max_floors', 'mean_floors', 'year_max', 'year_mean', 'commercial_ratio', 'x_normalized', 'y_normalized', 'x_normalized_2', 'y_normalized_2']]

# %%
hexes_summary.to_dict(orient='records')
# Out:
# [{'cost_mean_normalized': 0.31070960452542745,
#   'max_floors': 88,
#   'mean_floors': 6,
#   'year_max': 2015,
#   'year_mean': 1974,
#   'commercial_ratio': 0.6363636363636364,
#   'x_normalized': -1.7682364255227758,
#   'y_normalized': 0.05246117026397598,
#   'x_normalized_2': -1.0,
#   'y_normalized_2': 0.04383215352525372},
#  {'cost_mean_normalized': 0.0,
#   'max_floors': 14,
#   'mean_floors': 3,
#   'year_max': 1917,
#   'year_mean': 1968,
#   'commercial_ratio': 0.7572815533980582,
#   'x_normalized': -1.4963141734244292,
#   'y_normalized': 1.0524311207654213,
#   'x_normalized_2': -0.8414714549930415,
#   'y_normalized_2': 0.6343500374306894},
#  {'cost_mean_normalized': 1.0,
#   'max_floors': 80,
#   'mean_floors': 7,
#   'year_max': 2013,
#   'year_mean': 1964,
#   'commercial_ratio': 0.4830508474576271,
#   'x_normalized': -1.3170936655155319,
#   'y_normalized': -0.1388448352009454,
#   'x_normalized_2': -0.7369873013978078,
#   'y_normalized_2': -0.06922538969789611},
#  {'cost_mean_normalized': 0.24730054771790552,
#   'max_floors': 14,
#   'mean_floors': 4,
#   'year_max': 1917,
#   'year_mean': 1940,
#   'commercial_ratio': 0.7630522088353414,
#   'x_normalized': -1.138010199232703,
#   'y_normalized': -1.329479753736652,
#   'x_normalized_2': -0.632583041998133,
#   'y_normalized_2': -0.7731973485111924},
#  {'cost_mean_normalized': 0.21756164060582936,
#   'max_floors': 22,
#   'mean_floors': 5,
#   'year_max': 1974,
#   'year_mean': 1954,
#   'commercial_ratio': 0.6967592592592593,
#   'x_normalized': -1.0450941261505022,
#   'y_normalized': 0.8613221867755155,
#   'x_normalized_2': -0.5784136985191958,
#   'y_normalized_2': 0.5214934028502689},
#  {'cost_mean_normalized': 0.5141114571239116,
#   'max_floors': 34,
#   'mean_floors': 5,
#   'year_max': 1966,
#   'year_mean': 1941,
#   'commercial_ratio': 0.7107438016528925,
#   'x_normalized': -0.8659036601700548,
#   'y_normalized': -0.3302684262389711,
#   'x_normalized_2': -0.4739470591331507,
#   'y_normalized_2': -0.18240604503416324},
#  {'cost_mean_normalized': 0.9440576234259487,
#   'max_floors': 20,
#   'mean_floors': 5,
#   'year_max': 1981,
#   'year_mean': 1956,
#   'commercial_ratio': 0.5814696485623003,
#   'x_normalized': -0.686850380747747,
#   'y_normalized': -1.5212176388102108,
#   'x_normalized_2': -0.36956039843692806,
#   'y_normalized_2': -0.8865638325884052},
#  {'cost_mean_normalized': 0.3567750617370917,
#   'max_floors': 31,
#   'mean_floors': 5,
#   'year_max': 1954,
#   'year_mean': 1940,
#   'commercial_ratio': 0.6738159070598749,
#   'x_normalized': -0.5938268800323593,
#   'y_normalized': 0.6700957210326466,
#   'x_normalized_2': -0.3153284254885331,
#   'y_normalized_2': 0.4085673615821608},
#  {'cost_mean_normalized': 0.42868372716129743,
#   'max_floors': 26,
#   'mean_floors': 4,
#   'year_max': 1952,
#   'year_mean': 1928,
#   'commercial_ratio': 0.6604810996563574,
#   'x_normalized': -0.4146665537025433,
#   'y_normalized': -0.5218097113795666,
#   'x_normalized_2': -0.2108793572829441,
#   'y_normalized_2': -0.29565628790447374},
#  {'cost_mean_normalized': 0.2072038788134677,
#   'max_floors': 18,
#   'mean_floors': 5,
#   'year_max': 1979,
#   'year_mean': 1946,
#   'commercial_ratio': 0.7035087719298245,
#   'x_normalized': -0.3217800525408364,
#   'y_normalized': 1.671614696634635,
#   'x_normalized_2': -0.15672725400223556,
#   'y_normalized_2': 1.0},
#  {'cost_mean_normalized': 0.2685733315932321,
#   'max_floors': 23,
#   'mean_floors': 4,
#   'year_max': 1973,
#   'year_mean': 1933,
#   'commercial_ratio': 0.7914110429447853,
#   'x_normalized': -0.23564355890806682,
#   'y_normalized': -1.713073380014424,
#   'x_normalized_2': -0.1065103522877505,
#   'y_normalized_2': -1.0},
#  {'cost_mean_normalized': 0.3396041520127993,
#   'max_floors': 19,
#   'mean_floors': 4,
#   'year_max': 1999,
#   'year_mean': 1923,
#   'commercial_ratio': 0.7353673723536738,
#   'x_normalized': -0.1425125793515404,
#   'y_normalized': 0.4787516149931888,
#   'x_normalized_2': -0.05221572001606271,
#   'y_normalized_2': 0.2955718495274868},
#  {'cost_mean_normalized': 0.3178658946012479,
#   'max_floors': 22,
#   'mean_floors': 4,
#   'year_max': 1974,
#   'year_mean': 1934,
#   'commercial_ratio': 0.8275538894095595,
#   'x_normalized': 0.03661750956817132,
#   'y_normalized': -0.7134687992846376,
#   'x_normalized_2': 0.052189221362523436,
#   'y_normalized_2': -0.4089761825560065},
#  {'cost_mean_normalized': 0.2855537408547572,
#   'max_floors': 39,
#   'mean_floors': 5,
#   'year_max': 2018,
#   'year_mean': 1949,
#   'commercial_ratio': 0.7164179104477612,
#   'x_normalized': 0.12961134841606692,
#   'y_normalized': 1.480468350433991,
#   'x_normalized_2': 0.10637638857996339,
#   'y_normalized_2': 0.8871212721761713},
#  {'cost_mean_normalized': 0.2716823864263604,
#   'max_floors': 15,
#   'mean_floors': 4,
#   'year_max': 1951,
#   'year_mean': 1911,
#   'commercial_ratio': 0.7925675675675675,
#   'x_normalized': 0.30884863150621344,
#   'y_normalized': 0.2872897599810762,
#   'x_normalized_2': 0.21081729295311566,
#   'y_normalized_2': 0.1825068025091577},
#  {'cost_mean_normalized': 0.2465724102456586,
#   'max_floors': 35,
#   'mean_floors': 5,
#   'year_max': 2004,
#   'year_mean': 1931,
#   'commercial_ratio': 0.7577045696068013,
#   'x_normalized': 0.48794838521996464,
#   'y_normalized': -0.9052457987508209,
#   'x_normalized_2': 0.31517805946543354,
#   'y_normalized_2': -0.5223657933156012},
#  {'cost_mean_normalized': 0.25721537731842437,
#   'max_floors': 29,
#   'mean_floors': 5,
#   'year_max': 1955,
#   'year_mean': 1945,
#   'commercial_ratio': 0.7536231884057971,
#   'x_normalized': 0.5810496128505401,
#   'y_normalized': 1.2892043094779462,
#   'x_normalized_2': 0.36942780173081696,
#   'y_normalized_2': 0.7741730414059078},
#  {'cost_mean_normalized': 0.127354786141074,
#   'max_floors': 33,
#   'mean_floors': 4,
#   'year_max': 1953,
#   'year_mean': 1921,
#   'commercial_ratio': 0.7554347826086957,
#   'x_normalized': 0.7602566080530236,
#   'y_normalized': 0.09571004718467865,
#   'x_normalized_2': 0.4738510574634378,
#   'y_normalized_2': 0.06937215627002927},
#  {'cost_mean_normalized': 0.22942849497793155,
#   'max_floors': 24,
#   'mean_floors': 5,
#   'year_max': 1967,
#   'year_mean': 1936,
#   'commercial_ratio': 0.7511415525114156,
#   'x_normalized': 0.9393259287277493,
#   'y_normalized': -1.097140818708443,
#   'x_normalized_2': 0.5781940907560603,
#   'y_normalized_2': -0.6358251845891426},
#  {'cost_mean_normalized': 0.0804320460512608,
#   'max_floors': 22,
#   'mean_floors': 4,
#   'year_max': 1974,
#   'year_mean': 1940,
#   'commercial_ratio': 0.7938856015779092,
#   'x_normalized': 1.0325345962088677,
#   'y_normalized': 1.0978224649438337,
#   'x_normalized_2': 0.6325064378264427,
#   'y_normalized_2': 0.6611552434255477},
#  {'cost_mean_normalized': 0.1757200999225153,
#   'max_floors': 23,
#   'mean_floors': 4,
#   'year_max': 1973,
#   'year_mean': 1938,
#   'commercial_ratio': 0.8062755798090041,
#   'x_normalized': 1.2117112056991208,
#   'y_normalized': -0.0959876323400742,
#   'x_normalized_2': 0.7369119879165174,
#   'y_normalized_2': -0.04388574227320024},
#  {'cost_mean_normalized': 0.1554701918139143,
#   'max_floors': 19,
#   'mean_floors': 5,
#   'year_max': 1999,
#   'year_mean': 1956,
#   'commercial_ratio': 0.6432432432432432,
#   'x_normalized': 1.3907499954644653,
#   'y_normalized': -1.2891539682204793,
#   'x_normalized_2': 0.8412372309607488,
#   'y_normalized_2': -0.7493544208609451},
#  {'cost_mean_normalized': 0.055106169102181704,
#   'max_floors': 22,
#   'mean_floors': 4,
#   'year_max': 1974,
#   'year_mean': 1945,
#   'commercial_ratio': 0.8053596614950634,
#   'x_normalized': 1.484066153834701,
#   'y_normalized': 0.9063227078730067,
#   'x_normalized_2': 0.8956122125761196,
#   'y_normalized_2': 0.5480678138911275},
#  {'cost_mean_normalized': 0.22456411978472018,
#   'max_floors': 25,
#   'mean_floors': 6,
#   'year_max': 1951,
#   'year_mean': 1974,
#   'commercial_ratio': 0.8018018018018018,
#   'x_normalized': 1.663212279751031,
#   'y_normalized': -0.2878033876717755,
#   'x_normalized_2': 1.0,
#   'y_normalized_2': -0.1572982677332959}]

# %%
with open('data/data_visualization.json', 'w') as json_file:
    json.dump({'features': hexes_summary.to_dict(orient='records')}, json_file)
